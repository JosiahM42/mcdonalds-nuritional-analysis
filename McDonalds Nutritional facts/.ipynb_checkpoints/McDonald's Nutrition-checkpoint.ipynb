# %% [markdown]
# # McDonald's Nutrition: What you should have if you are on a specific diet
#
# McDonald's is one of the worlds largest fast food resturants and according to Lock(2020) as of 2019, there were a total of 38,695 franchised restaurants globally. McDonald's food is globally regarded as rather unhealthy for you, but in this notebook, I want to show that even though you maybe on a diet, you can still enjoy McDonald's to its fullest. In this notebook I will be using a kaggle dataset called Nutrition Facts for McDonald's Menu by McDonalds, to try to change societal perceptions of fast food. By no means am I a qualified dietiton, I just felt like looking into the topic.
#
# This notebook will cover the following:
#
#     * What is the unhealthiest food option on McDonald's menu?
#
#     * What is the healthiest food option on the McDonald's menu?
#
#     * What is the healthiest drinks option on the McDonald's menu?
#
#     * What can you eat if you are on a low carb diet?
#
#     * What can you eat if you are on a low fat diet?
#
#     * What can you eat if you are on a high protein diet?

# %% [markdown]
# # Data preparation
#
# Before we start analysing the data and making assumptions, we need to load the data into the notebook.

# %%
# Allows for the use of linear algebra
import numpy as np

# Allows for the use of data processing 
import pandas as pd

# Allows for the use of graphs
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Reads the csv file and stores it as a dataFrame within a variable
menu_dataset = pd.read_csv('menu.csv')

# Displays the first 5 dataFrame rows
menu_dataset.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
# 2                             42        0.0  ...             29
# 3                             52        0.0  ...             30
# 4                             42        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# 2                             10              4
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
# [5 rows x 24 columns]

# %%
# Shows if any of the columns have missing values
menu_dataset.isnull()
# Out:
#      Category   Item  Serving Size  Calories  Calories from Fat  Total Fat  \
# 0       False  False         False     False              False      False
# 1       False  False         False     False              False      False
# 2       False  False         False     False              False      False
# 3       False  False         False     False              False      False
# 4       False  False         False     False              False      False
# ..        ...    ...           ...       ...                ...        ...
# 255     False  False         False     False              False      False
# 256     False  False         False     False              False      False
# 257     False  False         False     False              False      False
# 258     False  False         False     False              False      False
# 259     False  False         False     False              False      False
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                        False          False                          False
# 1                        False          False                          False
# 2                        False          False                          False
# 3                        False          False                          False
# 4                        False          False                          False
# ..                         ...            ...                            ...
# 255                      False          False                          False
# 256                      False          False                          False
# 257                      False          False                          False
# 258                      False          False                          False
# 259                      False          False                          False
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0        False  ...          False                          False
# 1        False  ...          False                          False
# 2        False  ...          False                          False
# 3        False  ...          False                          False
# 4        False  ...          False                          False
# ..         ...  ...            ...                            ...
# 255      False  ...          False                          False
# 256      False  ...          False                          False
# 257      False  ...          False                          False
# 258      False  ...          False                          False
# 259      False  ...          False                          False
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0            False                          False   False    False
# 1            False                          False   False    False
# 2            False                          False   False    False
# 3            False                          False   False    False
# 4            False                          False   False    False
# ..             ...                            ...     ...      ...
# 255          False                          False   False    False
# 256          False                          False   False    False
# 257          False                          False   False    False
# 258          False                          False   False    False
# 259          False                          False   False    False
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
# ..                         ...                        ...
# 255                      False                      False
# 256                      False                      False
# 257                      False                      False
# 258                      False                      False
# 259                      False                      False
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 0                      False                 False
# 1                      False                 False
# 2                      False                 False
# 3                      False                 False
# 4                      False                 False
# ..                       ...                   ...
# 255                    False                 False
# 256                    False                 False
# 257                    False                 False
# 258                    False                 False
# 259                    False                 False
#
# [260 rows x 24 columns]

# %% [markdown]
# From the output windows above, we can see that there are a total of 24 columns with no missing values.

# %% [markdown]
# In order to make data analysis slightly easier, I have separated each catagory into more sizable datasets using SQL techniques. The SQL script I used:

# %%
from IPython.display import Image
from IPython.display import display
breakfast = Image(filename='D:\\Jupyter Notebook\\DS projects\\mcdonalds-data-science\\McDonalds Nutritional facts\\SQL Images\\Breakfast.jpg')
mains = Image(filename='D:\\Jupyter Notebook\\DS projects\\mcdonalds-data-science\\McDonalds Nutritional facts\\SQL Images\\mains.jpg') 
drinks = Image(filename='D:\\Jupyter Notebook\\DS projects\\mcdonalds-data-science\\McDonalds Nutritional facts\\SQL Images\\Drinks.jpg') 
sides = Image(filename='D:\\Jupyter Notebook\\DS projects\\mcdonalds-data-science\\McDonalds Nutritional facts\\SQL Images\\Sides.jpg') 
display(breakfast, mains, drinks, sides)

# %%
breakfast_menu = pd.read_csv('breakfast.csv')

main_menu = pd.read_csv('mains_menu.csv')

beverage_menu = pd.read_csv('drinks_menu.csv')

extras_menu = pd.read_csv('extras_menu.csv')

# %% [markdown]
# # Data Analysis

# %%
# Creates a strip plot graph that shows the highest number of calories in the catgory column
catagory_plot = sns.stripplot(x='Category', y='Calories', data=menu_dataset, size=5)
# assigns labels to the x axis and sets them to a 45 degree angle
catagory_plot.set_xticklabels(catagory_plot.get_xticklabels(), rotation= 45)
plt.title('All McDonald\'s menu items by calorie')
plt.show()

# %%
# Identifies the top 5 highest calorie menu items
menu_dataset.nlargest(5, 'Calories')
# Out:
#           Category                                               Item  \
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 82  22.8 oz (646 g)      1880               1060      118.0
# 32  15.3 oz (434 g)      1150                540       60.0
# 31  14.8 oz (420 g)      1090                510       56.0
# 34  15.4 oz (437 g)      1050                450       50.0
# 33  14.9 oz (423 g)       990                410       46.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 82                        182           20.0                            101
# 32                         93           20.0                            100
# 31                         87           19.0                             96
# 34                         77           16.0                             81
# 33                         70           16.0                             78
#
#     Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 82        1.0  ...            118                             39
# 32        0.0  ...            116                             39
# 31        0.0  ...            111                             37
# 34        0.0  ...            115                             38
# 33        0.0  ...            110                             37
#
#     Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 82              6                             24       1       87
# 32              7                             28      17       36
# 31              6                             23      17       36
# 34              7                             28      18       35
# 33              6                             23      17       35
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 82                          0                         15
# 32                         15                          2
# 31                         15                          2
# 34                          4                          2
# 33                          0                          2
#
#     Calcium (% Daily Value)  Iron (% Daily Value)
# 82                        8                    25
# 32                       30                    40
# 31                       25                    40
# 34                       25                    30
# 33                       25                    30
#
# [5 rows x 24 columns]

# %% [markdown]
# From the data above, we can see that the top five unhealthiest menu items are:
#
#     1. 40 piece Chicken Nuggets
#
#     2. Big Breakfast with Hotcakes (Large Biscuit)
#
#     3. Big Breakfast with Hotcakes (Regular Biscuit)
#
#     4. Big Breakfast with Hotcakes and Egg Whites (Large Biscuit)
#
#     5. Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)
#
# This is quite a suprising result because I was not expecting so many breakfast menu items to be so high in calories compared to the lunch menu.

# %%
# Identifies the top 5 lowest calorie menu items
menu_dataset.nsmallest(5, 'Calories')
# Out:
#       Category                    Item  Serving Size  Calories  \
# 114  Beverages       Diet Coke (Small)  16 fl oz cup         0
# 115  Beverages      Diet Coke (Medium)  21 fl oz cup         0
# 116  Beverages       Diet Coke (Large)  30 fl oz cup         0
# 117  Beverages       Diet Coke (Child)  12 fl oz cup         0
# 122  Beverages  Diet Dr Pepper (Small)  16 fl oz cup         0
#
#      Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 114                  0        0.0                          0            0.0
# 115                  0        0.0                          0            0.0
# 116                  0        0.0                          0            0.0
# 117                  0        0.0                          0            0.0
# 122                  0        0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 114                              0        0.0  ...              0
# 115                              0        0.0  ...              0
# 116                              0        0.0  ...              0
# 117                              0        0.0  ...              0
# 122                              0        0.0  ...              0
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 114                              0              0
# 115                              0              0
# 116                              0              0
# 117                              0              0
# 122                              0              0
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 114                              0       0        0
# 115                              0       0        0
# 116                              0       0        0
# 117                              0       0        0
# 122                              0       0        2
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 114                          0                          0
# 115                          0                          0
# 116                          0                          0
# 117                          0                          0
# 122                          0                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 114                        0                     0
# 115                        0                     0
# 116                        0                     0
# 117                        0                     0
# 122                        0                     0
#
# [5 rows x 24 columns]

# %% [markdown]
# Now, I was expecting the lowest calorie menu items to be drinks because most diet drinks are zero calorie.

# %% [markdown]
# ## Unhealthiest menu items by catagory
#
# Within this section I will be identifying the most unhealthy breakfast item, main menu item, drinks menu item and side menu items.

# %% [markdown]
# ### Unhealthy Breakfast Menu

# %%
# Creates a strip plot graph that shows the highest number of calories in the catgory column
breakfast_plot = sns.stripplot(x='Catagory', y='Calories', data=breakfast_menu, size=7)
# assigns labels to the x axis and sets them to a 45 degree angle
breakfast_plot.set_xticklabels(breakfast_plot.get_xticklabels())
plt.title('McDonald\'s breakfast menu items by calorie')
plt.show()

# %%
# Identifies the top 5 highest calorie menu items
breakfast_menu.nlargest(5, 'Calories')
# Out:
#      Catagory                                           Item     Serving_Size  \
# 32  Breakfast    Big Breakfast with Hotcakes (Large Biscuit)  15.3 oz (434 g)
# 31  Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)  14.8 oz (420 g)
# 34  Breakfast  Big Breakfast with Hotcakes and Egg Whites (L  15.4 oz (437 g)
# 33  Breakfast  Big Breakfast with Hotcakes and Egg Whites (R  14.9 oz (423 g)
# 28  Breakfast                  Big Breakfast (Large Biscuit)    10 oz (283 g)
#
#     Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 32      1150           540         60               93             20
# 31      1090           510         56               87             19
# 34      1050           450         50               77             16
# 33       990           410         46               70             16
# 28       800           470         52               80             18
#
#     Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 32                  100          0  ...            116                   39
# 31                   96          0  ...            111                   37
# 34                   81          0  ...            115                   38
# 33                   78          0  ...            110                   37
# 28                   90          0  ...             56                   19
#
#     Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  \
# 32              7                   28      17       36         15          2
# 31              6                   23      17       36         15          2
# 34              7                   28      18       35          4          2
# 33              6                   23      17       35          0          2
# 28              4                   17       3       28         15          2
#
#     Calcium_Daily  Iron_Daily
# 32             30          40
# 31             25          40
# 34             25          30
# 33             25          30
# 28             15          30
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Healthiest Breakfast menu items

# %%
# Identifies the top 5 lowest calorie menu items
breakfast_menu.nsmallest(5, 'Calories')
# Out:
#      Catagory                                       Item    Serving_Size  \
# 38  Breakfast                                 Hash Brown     2 oz (56 g)
# 1   Breakfast                          Egg White Delight  4.8 oz (135 g)
# 41  Breakfast  Fruit & Maple Oatmeal without Brown Sugar  9.6 oz (251 g)
# 40  Breakfast                      Fruit & Maple Oatmeal  9.6 oz (251 g)
# 0   Breakfast                               Egg McMuffin  4.8 oz (136 g)
#
#     Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 38       150            80          9               14              2
# 1        250            70          8               12              3
# 41       260            40          4                6              2
# 40       290            35          4                6              2
# 0        300           120         13               20              5
#
#     Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 38                    6          0  ...             15                    5
# 1                    15          0  ...             30                   10
# 41                    8          0  ...             49                   16
# 40                    8          0  ...             58                   19
# 0                    25          0  ...             31                   10
#
#     Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  \
# 38              2                    6       0        1          0          2
# 1               4                   17       3       18          6          0
# 41              5                   22      18        5          2        130
# 40              5                   19      32        5          2        130
# 0               4                   17       3       17         10          0
#
#     Calcium_Daily  Iron_Daily
# 38              0           2
# 1              25           8
# 41              6          10
# 40             10          10
# 0              25          15
#
# [5 rows x 24 columns]

# %% [markdown]
# pass

# %% [markdown]
# ### Unhealthiest main menu items
#
# Now we will look at what main menu items you should probably avoid or should eat if you are looking to stay healthy.

# %%
# Creates a strip plot graph that shows the highest number of calories in the main menu catagory column
main_plot = sns.stripplot(x='Catagory', y='Calories', data=main_menu, size=7)
# assigns labels to the x axis and sets them to a 45 degree angle
main_plot.set_xticklabels(main_plot.get_xticklabels(), rotation= 45)
plt.title('McDonald\'s main menu items by calorie')
plt.show()

# %%
# select rows that equal to beef & pork from the catagory column
beef_pork = main_menu.loc[main_menu['Catagory'] == 'Beef & Pork']

# outputs the top 5 rows with the highest calories
beef_pork.nlargest(5, 'Calories')
# Out:
#       Catagory                                       Item    Serving_Size  \
# 5  Beef & Pork         Double Quarter Pounder with Cheese   10 oz (283 g)
# 9  Beef & Pork                     Bacon Clubhouse Burger  9.5 oz (270 g)
# 3  Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
# 2  Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# 4  Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
#
#    Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 5       750           380         43               66             19
# 9       720           360         40               62             15
# 3       610           280         31               48             13
# 2       600           260         29               45             13
# 4       540           250         27               42             11
#
#    Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 5                   96          3  ...             42                   14
# 9                   75          2  ...             51                   17
# 3                   64          2  ...             46                   15
# 2                   63          2  ...             48                   16
# 4                   54          2  ...             45                   15
#
#    Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  \
# 5              3                   11      10       48         10          2
# 9              4                   14      14       39          8         25
# 3              3                   14      10       37          8         20
# 2              3                   12      12       37          6         15
# 4              3                   13       9       29         10          8
#
#    Calcium_Daily  Iron_Daily
# 5             30          35
# 9             30          25
# 3             25          30
# 2             25          30
# 4             25          30
#
# [5 rows x 24 columns]

# %%
chicken_fish = main_menu.loc[main_menu['Catagory'] == 'Chicken & Fish']

chicken_fish.nlargest(5, 'Calories')
# Out:
#           Catagory                                           Item  \
# 40  Chicken & Fish                   Chicken McNuggets (40 piece)
# 39  Chicken & Fish                   Chicken McNuggets (20 piece)
# 21  Chicken & Fish        Bacon Clubhouse Crispy Chicken Sandwich
# 17  Chicken & Fish           Premium Crispy Chicken Club Sandwich
# 32  Chicken & Fish  Premium McWrap Southwest Chicken (Crispy Chic
#
#        Serving_Size  Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  \
# 40  22.8 oz (646 g)      1880          1060        118              182
# 39  11.4 oz (323 g)       940           530         59               91
# 21    10 oz (284 g)       750           340         38               59
# 17   8.8 oz (249 g)       670           300         33               51
# 32  11.1 oz (314 g)       670           300         33               51
#
#     Saturated_Fat  Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  \
# 40             20                  101          1  ...            118
# 39             10                   50          0  ...             59
# 21             10                   51          1  ...             65
# 17              9                   44          0  ...             58
# 32              8                   40          1  ...             68
#
#     Carbohydrates_Daily  Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  \
# 40                   39              6                   24       1       87
# 39                   20              3                   12       0       44
# 21                   22              4                   15      16       36
# 17                   19              3                   14      11       36
# 32                   23              5                   19      12       27
#
#     Vitamin_A  Vitamin_C  Calcium_Daily  Iron_Daily
# 40          0         15              8          25
# 39          0          8              4          10
# 21          8         25             30          15
# 17          8         20             30          20
# 32         60         15             20          20
#
# [5 rows x 24 columns]

# %%
salads = main_menu.loc[main_menu['Catagory'] == 'Salads']

salads.nlargest(5, 'Calories')
# Out:
#    Catagory                                           Item     Serving_Size  \
# 46   Salads    Premium Southwest Salad with Crispy Chicken  12.3 oz (348 g)
# 43   Salads  Premium Bacon Ranch Salad with Crispy Chicken     9 oz (255 g)
# 47   Salads   Premium Southwest Salad with Grilled Chicken  11.8 oz (335 g)
# 44   Salads  Premium Bacon Ranch Salad with Grilled Chicke   8.5 oz (241 g)
# 42   Salads    Premium Bacon Ranch Salad (without Chicken)   7.9 oz (223 g)
#
#     Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 46       450           190         22               33              5
# 43       380           190         21               33              6
# 47       290            80          8               13              3
# 44       220            80          8               13              4
# 42       140            70          7               11              4
#
#     Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 46                   22          0  ...             42                   14
# 43                   29          0  ...             22                    7
# 47                   13          0  ...             28                    9
# 44                   20          0  ...              8                    3
# 42                   18          0  ...             10                    3
#
#     Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  \
# 46              7                   28      12       23        170         30
# 43              2                   10       5       25        100         25
# 47              7                   28      10       27        170         30
# 44              2                   10       4       29        110         30
# 42              3                   12       4        9        170         30
#
#     Calcium_Daily  Iron_Daily
# 46             15          15
# 43             15           8
# 47             15          15
# 44             15           8
# 42             15           6
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Healthiest Main Menu items

# %%
# select rows that equal to beef & pork from the catagory column
beef_pork = main_menu.loc[main_menu['Catagory'] == 'Beef & Pork']

# outputs the top 5 rows with the lowest calories
beef_pork.nsmallest(5, 'Calories')
# Out:
#        Catagory                 Item    Serving_Size  Calories  Calories_Fat  \
# 6   Beef & Pork            Hamburger   3.5 oz (98 g)       240            70
# 7   Beef & Pork         Cheeseburger    4 oz (113 g)       290           100
# 10  Beef & Pork             McDouble  5.2 oz (147 g)       380           150
# 8   Beef & Pork  Double Cheeseburger  5.7 oz (161 g)       430           190
# 12  Beef & Pork         Daily Double  6.7 oz (190 g)       430           200
#
#     Total_Fat  Total_Daily_Fat  Saturated_Fat  Saturated_Daily_Fat  Trans_Fat  \
# 6           8               12              3                   15          0
# 7          11               18              5                   27          1
# 10         17               26              8                   40          1
# 8          21               32             10                   52          1
# 12         22               35              9                   44          1
#
#     ...  Carbohydrates  Carbohydrates_Daily  Dietary_Fibre  \
# 6   ...             32                   11              1
# 7   ...             33                   11              2
# 10  ...             34                   11              2
# 8   ...             35                   12              2
# 12  ...             34                   11              2
#
#     Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  Calcium_Daily  \
# 6                     6       6       12          2          2             10
# 7                     7       7       15          6          2             20
# 10                    7       7       22          6          2             20
# 8                     8       7       24         10          2             30
# 12                    8       7       22          8          8             20
#
#     Iron_Daily
# 6           15
# 7           15
# 10          20
# 8           20
# 12          20
#
# [5 rows x 24 columns]

# %%
chicken_fish = main_menu.loc[main_menu['Catagory'] == 'Chicken & Fish']

chicken_fish.nsmallest(5, 'Calories')
# Out:
#           Catagory                                      Item    Serving_Size  \
# 36  Chicken & Fish               Chicken McNuggets (4 piece)   2.3 oz (65 g)
# 37  Chicken & Fish               Chicken McNuggets (6 piece)   3.4 oz (97 g)
# 16  Chicken & Fish  Premium Grilled Chicken Classic Sandwich    7 oz (200 g)
# 24  Chicken & Fish                                 McChicken  5.1 oz (143 g)
# 27  Chicken & Fish                   Buffalo Ranch McChicken  5.2 oz (148 g)
#
#     Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 36       190           110         12               18              2
# 37       280           160         18               27              3
# 16       350            80          9               13              2
# 24       360           140         16               25              3
# 27       360           150         16               25              3
#
#     Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 36                   10          0  ...             12                    4
# 37                   15          0  ...             18                    6
# 16                    9          0  ...             42                   14
# 24                   15          0  ...             40                   13
# 27                   16          0  ...             40                   13
#
#     Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  \
# 36              1                    2       0        9          0          2
# 37              1                    4       0       13          0          2
# 16              3                   13       8       28          4          8
# 24              2                    7       5       14          0          2
# 27              2                    7       5       14          2          2
#
#     Calcium_Daily  Iron_Daily
# 36              0           2
# 37              2           4
# 16             15          20
# 24             10          15
# 27             15          15
#
# [5 rows x 24 columns]

# %%
salads = main_menu.loc[main_menu['Catagory'] == 'Salads']

salads.nsmallest(5, 'Calories')
# Out:
#    Catagory                                           Item     Serving_Size  \
# 42   Salads    Premium Bacon Ranch Salad (without Chicken)   7.9 oz (223 g)
# 45   Salads      Premium Southwest Salad (without Chicken)   8.1 oz (230 g)
# 44   Salads  Premium Bacon Ranch Salad with Grilled Chicke   8.5 oz (241 g)
# 47   Salads   Premium Southwest Salad with Grilled Chicken  11.8 oz (335 g)
# 43   Salads  Premium Bacon Ranch Salad with Crispy Chicken     9 oz (255 g)
#
#     Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 42       140            70          7               11              4
# 45       140            40          5                7              2
# 44       220            80          8               13              4
# 47       290            80          8               13              3
# 43       380           190         21               33              6
#
#     Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 42                   18          0  ...             10                    3
# 45                    9          0  ...             20                    7
# 44                   20          0  ...              8                    3
# 47                   13          0  ...             28                    9
# 43                   29          0  ...             22                    7
#
#     Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  \
# 42              3                   12       4        9        170         30
# 45              6                   23       6        6        160         25
# 44              2                   10       4       29        110         30
# 47              7                   28      10       27        170         30
# 43              2                   10       5       25        100         25
#
#     Calcium_Daily  Iron_Daily
# 42             15           6
# 45             15          10
# 44             15           8
# 47             15          15
# 43             15           8
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Healthy and unhealthy Beverage menu items

# %%
# Creates a strip plot graph that shows the highest sugary drink in the catagory column
drinks_plot = sns.stripplot(x='Catagory', y='Sugars', data=beverage_menu, size=7)
# assigns labels to the x axis and sets them to a 45 degree angle
drinks_plot.set_xticklabels(drinks_plot.get_xticklabels(), rotation= 45)
plt.title('McDonald\'s drinks menu items by sugars')
plt.show()

# %% [markdown]
# ### Unhealthy Beverage menu items

# %%
beverages = beverage_menu.loc[beverage_menu['Catagory'] == 'Beverages']

beverages.nlargest(5, 'Sugars')
# Out:
#      Catagory                              Item  Serving_Size  Calories  \
# 2   Beverages         Coca-Cola Classic (Large)  30 fl oz cup       280
# 18  Beverages                    Sprite (Large)  30 fl oz cup       280
# 10  Beverages                 Dr Pepper (Large)  30 fl oz cup       270
# 25  Beverages  Minute Maid Orange Juice (Large)  22 fl oz cup       280
# 1   Beverages        Coca-Cola Classic (Medium)  21 fl oz cup       200
#
#     Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 2              0          0                0              0
# 18             0          0                0              0
# 10             0          0                0              0
# 25             0          0                0              0
# 1              0          0                0              0
#
#     Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 2                     0          0  ...             76                   25
# 18                    0          0  ...             74                   25
# 10                    0          0  ...             72                   24
# 25                    0          0  ...             65                   22
# 1                     0          0  ...             55                   18
#
#     Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  \
# 2               0                    0      76        0          0          0
# 18              0                    0      74        0          0          0
# 10              0                    0      70        0          0          0
# 25              0                    0      58        4          0        240
# 1               0                    0      55        0          0          0
#
#     Calcium_Daily  Iron_Daily
# 2               0           0
# 18              0           0
# 10              0           0
# 25              4           0
# 1               0           0
#
# [5 rows x 24 columns]

# %%
tea_coffee = beverage_menu.loc[beverage_menu['Catagory'] == 'Coffee & Tea']

tea_coffee.nlargest(5, 'Sugars')
# Out:
#          Catagory                            Item  Serving_Size  Calories  \
# 121  Coffee & Tea   Frappé Chocolate Chip (Large)  22 fl oz cup       760
# 115  Coffee & Tea            Frappé Mocha (Large)  22 fl oz cup       670
# 118  Coffee & Tea          Frappé Caramel (Large)  22 fl oz cup       670
# 120  Coffee & Tea  Frappé Chocolate Chip (Medium)  16 fl oz cup       630
# 114  Coffee & Tea           Frappé Mocha (Medium)  16 fl oz cup       550
#
#      Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 121           280         31               48             20
# 115           240         26               41             17
# 118           250         27               42             17
# 120           240         26               41             17
# 114           200         22               34             14
#
#      Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 121                  101          2  ...            111                   37
# 115                   85          1  ...             98                   33
# 118                   87          2  ...             96                   32
# 120                   85          1  ...             91                   30
# 114                   71          1  ...             80                   27
#
#      Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  \
# 121              1                    5      99       12         20
# 115              1                    4      88       11         20
# 118              0                    0      88       11         20
# 120              1                    5      81        9         15
# 114              1                    4      71        9         15
#
#      Vitamin_C  Calcium_Daily  Iron_Daily
# 121          0             35           6
# 115          0             35           4
# 118          0             35           2
# 120          0             30           4
# 114          0             25           4
#
# [5 rows x 24 columns]

# %%
shakes_smoothies = beverage_menu.loc[beverage_menu['Catagory'] == 'Smoothies & Shakes']

shakes_smoothies.nlargest(5, 'Sugars')
# Out:
#                Catagory                                           Item  \
# 143  Smoothies & Shakes           McFlurry with M&M’s Candies (Medium)
# 136  Smoothies & Shakes                       Strawberry Shake (Large)
# 139  Smoothies & Shakes                        Chocolate Shake (Large)
# 141  Smoothies & Shakes                         Shamrock Shake (Large)
# 148  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Med
#
#         Serving_Size  Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  \
# 143  16.2 oz (460 g)       930           290         33               50
# 136     22 fl oz cup       850           210         24               36
# 139     22 fl oz cup       850           210         23               36
# 141     22 fl oz cup       820           210         23               35
# 148  14.2 oz (403 g)       810           290         32               50
#
#      Saturated_Fat  Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  \
# 143             20                  102          1  ...            139
# 136             15                   75          1  ...            140
# 139             15                   74          1  ...            141
# 141             15                   73          1  ...            135
# 148             15                   76          1  ...            114
#
#      Carbohydrates_Daily  Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  \
# 143                   46              2                    7     128       20
# 136                   47              0                    0     123       18
# 139                   47              2                    8     120       19
# 141                   45              0                    0     115       18
# 148                   38              2                    9     103       21
#
#      Vitamin_A  Vitamin_C  Calcium_Daily  Iron_Daily
# 143         25          0             70          10
# 136         30          0             70           0
# 139         30          0             60          15
# 141         30          0             60           0
# 148         20          0             60           6
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Healthiest Beverage Menu Items

# %%
beverages.nsmallest(5, 'Sugars')
# Out:
#      Catagory                    Item  Serving_Size  Calories  Calories_Fat  \
# 4   Beverages       Diet Coke (Small)  16 fl oz cup         0             0
# 5   Beverages      Diet Coke (Medium)  21 fl oz cup         0             0
# 6   Beverages       Diet Coke (Large)  30 fl oz cup         0             0
# 7   Beverages       Diet Coke (Child)  12 fl oz cup         0             0
# 12  Beverages  Diet Dr Pepper (Small)  16 fl oz cup         0             0
#
#     Total_Fat  Total_Daily_Fat  Saturated_Fat  Saturated_Daily_Fat  Trans_Fat  \
# 4           0                0              0                    0          0
# 5           0                0              0                    0          0
# 6           0                0              0                    0          0
# 7           0                0              0                    0          0
# 12          0                0              0                    0          0
#
#     ...  Carbohydrates  Carbohydrates_Daily  Dietary_Fibre  \
# 4   ...              0                    0              0
# 5   ...              0                    0              0
# 6   ...              0                    0              0
# 7   ...              0                    0              0
# 12  ...              0                    0              0
#
#     Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  Calcium_Daily  \
# 4                     0       0        0          0          0              0
# 5                     0       0        0          0          0              0
# 6                     0       0        0          0          0              0
# 7                     0       0        0          0          0              0
# 12                    0       0        2          0          0              0
#
#     Iron_Daily
# 4            0
# 5            0
# 6            0
# 7            0
# 12           0
#
# [5 rows x 24 columns]

# %%
tea_coffee.nsmallest(5, 'Sugars')
# Out:
#         Catagory               Item  Serving_Size  Calories  Calories_Fat  \
# 27  Coffee & Tea   Iced Tea (Small)  16 fl oz cup         0             0
# 28  Coffee & Tea  Iced Tea (Medium)  21 fl oz cup         0             0
# 29  Coffee & Tea   Iced Tea (Large)  30 fl oz cup         0             0
# 30  Coffee & Tea   Iced Tea (Child)  12 fl oz cup         0             0
# 35  Coffee & Tea     Coffee (Small)  12 fl oz cup         0             0
#
#     Total_Fat  Total_Daily_Fat  Saturated_Fat  Saturated_Daily_Fat  Trans_Fat  \
# 27          0                0              0                    0          0
# 28          0                0              0                    0          0
# 29          0                0              0                    0          0
# 30          0                0              0                    0          0
# 35          0                0              0                    0          0
#
#     ...  Carbohydrates  Carbohydrates_Daily  Dietary_Fibre  \
# 27  ...              0                    0              0
# 28  ...              0                    0              0
# 29  ...              0                    0              0
# 30  ...              0                    0              0
# 35  ...              0                    0              0
#
#     Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  Calcium_Daily  \
# 27                    0       0        0          0          0              0
# 28                    0       0        0          0          0              0
# 29                    0       0        0          0          0              0
# 30                    0       0        0          0          0              0
# 35                    0       0        0          0          0              0
#
#     Iron_Daily
# 27           0
# 28           0
# 29           0
# 30           0
# 35           0
#
# [5 rows x 24 columns]

# %%
shakes_smoothies.nsmallest(5, 'Sugars')
# Out:
#                Catagory                                           Item  \
# 147  Smoothies & Shakes             McFlurry with Oreo Cookies (Snack)
# 122  Smoothies & Shakes         Blueberry Pomegranate Smoothie (Small)
# 125  Smoothies & Shakes             Strawberry Banana Smoothie (Small)
# 128  Smoothies & Shakes               Mango Pineapple Smoothie (Small)
# 149  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Sna
#
#        Serving_Size  Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  \
# 147  6.7 oz (190 g)       340           100         11               17
# 122    12 fl oz cup       220             5          1                1
# 125    12 fl oz cup       210             5          1                1
# 128    12 fl oz cup       210             5          1                1
# 149  7.1 oz (202 g)       410           150         16               25
#
#      Saturated_Fat  Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  \
# 147              6                   29          0  ...             53
# 122              0                    0          0  ...             50
# 125              0                    0          0  ...             47
# 128              0                    0          0  ...             50
# 149              8                   38          0  ...             57
#
#      Carbohydrates_Daily  Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  \
# 147                   18              1                    2      43        8
# 122                   17              3                   12      44        2
# 125                   16              3                   10      44        3
# 128                   17              1                    4      46        2
# 149                   19              1                    5      51       10
#
#      Vitamin_A  Vitamin_C  Calcium_Daily  Iron_Daily
# 147         10          0             25           6
# 122          0          2              6           2
# 125          0         30              8           2
# 128         30         20              8           2
# 149         10          0             30           4
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Unhealthiest side menu items

# %%
# Creates a strip plot graph that shows the highest sugary drink in the catagory column
sides_plot = sns.stripplot(x='Catagory', y='Calories', data=extras_menu, size=7)
# assigns labels to the x axis and sets them to a 45 degree angle
sides_plot.set_xticklabels(sides_plot.get_xticklabels(), rotation= 45)
plt.title('McDonald\'s sides menu items by calories')
plt.show()

# %%
snacks_sides = extras_menu.loc[extras_menu['Catagory'] == 'Snacks & Sides']

snacks_sides.nlargest(5, 'Calories')
# Out:
#          Catagory                                       Item    Serving_Size  \
# 8  Snacks & Sides                         Large French Fries  5.9 oz (168 g)
# 4  Snacks & Sides          Ranch Snack Wrap (Crispy Chicken)  4.5 oz (128 g)
# 0  Snacks & Sides   Chipotle BBQ Snack Wrap (Crispy Chicken)  4.6 oz (130 g)
# 7  Snacks & Sides                        Medium French Fries  3.9 oz (111 g)
# 2  Snacks & Sides  Honey Mustard Snack Wrap (Crispy Chicken)  4.3 oz (123 g)
#
#    Calories  Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 8       510           220         24               37              4
# 4       360           180         20               30              5
# 0       340           130         15               23              5
# 7       340           140         16               24              3
# 2       330           130         15               23              5
#
#    Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 8                   17          0  ...             67                   22
# 4                   27          0  ...             32                   11
# 0                   22          0  ...             37                   12
# 7                   11          0  ...             44                   15
# 2                   22          0  ...             34                   11
#
#    Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  \
# 8              5                   22       0        6          0         70
# 4              1                    5       3       15          2          0
# 0              1                    6       8       14          4          0
# 7              4                   14       0        4          0         45
# 2              1                    5       3       14          2          0
#
#    Calcium_Daily  Iron_Daily
# 8              2           8
# 4             10          10
# 0             10          10
# 7              2           4
# 2             10          10
#
# [5 rows x 24 columns]

# %%
desserts = extras_menu.loc[extras_menu['Catagory'] == 'Desserts']

desserts.nlargest(5, 'Calories')
# Out:
#     Catagory                   Item     Serving_Size  Calories  Calories_Fat  \
# 18  Desserts     Hot Caramel Sundae   6.4 oz (182 g)       340            70
# 17  Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330            80
# 19  Desserts      Strawberry Sundae   6.3 oz (178 g)       280            60
# 13  Desserts        Baked Apple Pie    2.7 oz (77 g)       250           110
# 14  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160            70
#
#     Total_Fat  Total_Daily_Fat  Saturated_Fat  Saturated_Daily_Fat  Trans_Fat  \
# 18          8               12              5                   24          0
# 17          9               14              7                   34          0
# 19          6               10              4                   20          0
# 13         13               19              7                   35          0
# 14          8               12              4                   19          0
#
#     ...  Carbohydrates  Carbohydrates_Daily  Dietary_Fibre  \
# 18  ...             60                   20              0
# 17  ...             53                   18              1
# 19  ...             49                   16              0
# 13  ...             32                   11              4
# 14  ...             21                    7              1
#
#     Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  Calcium_Daily  \
# 18                    0      43        7         10          0             25
# 17                    3      48        8          8          0             25
# 19                    0      45        6          8          4             20
# 13                   15      13        2          4         25              2
# 14                    3      15        2          2          0              2
#
#     Iron_Daily
# 18           0
# 17           8
# 19           0
# 13           6
# 14           8
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Healthiest side menu items

# %%
snacks_sides.nsmallest(5, 'Calories')
# Out:
#           Catagory                     Item    Serving_Size  Calories  \
# 11  Snacks & Sides             Apple Slices   1.2 oz (34 g)        15
# 10  Snacks & Sides               Side Salad   3.1 oz (87 g)        20
# 9   Snacks & Sides        Kids French Fries   1.3 oz (38 g)       110
# 12  Snacks & Sides  Fruit 'n Yogurt Parfait  5.2 oz (149 g)       150
# 6   Snacks & Sides       Small French Fries   2.6 oz (75 g)       230
#
#     Calories_Fat  Total_Fat  Total_Daily_Fat  Saturated_Fat  \
# 11             0          0                0              0
# 10             0          0                0              0
# 9             50          5                8              1
# 12            20          2                3              1
# 6            100         11               17              2
#
#     Saturated_Daily_Fat  Trans_Fat  ...  Carbohydrates  Carbohydrates_Daily  \
# 11                    0          0  ...              4                    1
# 10                    0          0  ...              4                    1
# 9                     4          0  ...             15                    5
# 12                    5          0  ...             30                   10
# 6                     8          0  ...             30                   10
#
#     Dietary_Fibre  Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  \
# 11              0                    0       3        0          0        160
# 10              1                    6       2        1         45         25
# 9               1                    5       0        1          0         15
# 12              1                    3      23        4          2         15
# 6               2                   10       0        2          0         30
#
#     Calcium_Daily  Iron_Daily
# 11              2           0
# 10              2           4
# 9               0           2
# 12             10           4
# 6               0           4
#
# [5 rows x 24 columns]

# %%
desserts.nsmallest(5, 'Calories')
# Out:
#     Catagory                   Item     Serving_Size  Calories  Calories_Fat  \
# 16  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45            10
# 15  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150            50
# 14  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160            70
# 13  Desserts        Baked Apple Pie    2.7 oz (77 g)       250           110
# 19  Desserts      Strawberry Sundae   6.3 oz (178 g)       280            60
#
#     Total_Fat  Total_Daily_Fat  Saturated_Fat  Saturated_Daily_Fat  Trans_Fat  \
# 16          2                2              1                    4          0
# 15          6                9              3                   13          0
# 14          8               12              4                   19          0
# 13         13               19              7                   35          0
# 19          6               10              4                   20          0
#
#     ...  Carbohydrates  Carbohydrates_Daily  Dietary_Fibre  \
# 16  ...              7                    2              0
# 15  ...             22                    7              1
# 14  ...             21                    7              1
# 13  ...             32                   11              4
# 19  ...             49                   16              0
#
#     Dietary_Fibre_Daily  Sugars  Protein  Vitamin_A  Vitamin_C  Calcium_Daily  \
# 16                    0       6        1          2          0              4
# 15                    3      13        2          2          0              2
# 14                    3      15        2          2          0              2
# 13                   15      13        2          4         25              2
# 19                    0      45        6          8          4             20
#
#     Iron_Daily
# 16           0
# 15           6
# 14           8
# 13           6
# 19           0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## What can you eat at McDonald's on a diet?
#
# Based on the results above you may be thinking "What can I eat on specific diet at McDonald's?", Well that question cannot be solved using data alone because of external factors that are unique to each customer. However, with data we can generalise each diet enableing us to identify some great options.
#
# From just this data alone, we cannot accurately suggest options for customers on plant-based(1), paleo(2) or similar diets due to the simple fact that we do not know what ingredients are in each product. We could make assuptions based on product names but as stated earlier, the data does not show possible ingredients. For instance, we can assume that the McChicken is a high protein product, yet, we can also assume that it also contains traces of wheat.
#
# (1) Plant based diets according to the Association of UK Dietitians (N/A), " are based on foods derived from plants, including vegetables, wholegrains, legumes, nuts, seeds and fruits, with few or no animal products ".
#
# (2) A paleo diet according to dictionary.com (N/A), is " a diet based on foods which adherents presume were available to Paleolithic humans. This often includes low grain consumption and high intake of protein and vegetables ".
#
# So, we are going to start off with what you could eat on a low carbohydrate diet.

# %% [markdown]
# ### Low Carbohydrate Diet
#
# There are quite a few different types of low carb diet, but according to Diabetes UK (N/A), they all have one thing in common, the fact that to reduce the total amount of carbohydrate you eat in a day, you must limit your carb intake to less than 130g a day. However, during the day you should <ins>increase the amount of protein and fat you intake</ins> (But not by much), according to Bjarnadottir (2019).
#
# From this we can gain a sufficent amount of data, that we can use to make somewhat accurate suggestions.

# %%
# Uses matplotlib's subplot function to create grouped scatter plots
# subplots parameters state that there will be a row of 3 plots with a size of 20 by 5
fig, ax = plt.subplots(1,3, figsize=(20,5))
# figsize=(12,5)
ax[0].scatter(menu_dataset['Category'], menu_dataset['Carbohydrates'], edgecolor='black')
ax[0].set_title('Carbohydrates', fontsize=14)
# sets the labels of the x axis to a 45 degree angle
ax[0].tick_params(labelrotation=45)

ax[1].scatter(menu_dataset['Category'], menu_dataset['Carbohydrates (% Daily Value)'],
               edgecolor='black')
ax[1].set_title('Carbohydrates Daily', fontsize=14)
ax[1].tick_params(labelrotation=45)

ax[2].scatter(menu_dataset['Category'], menu_dataset['Protein'], edgecolor='black')
ax[2].set_title('Protein', fontsize=14)
ax[2].tick_params(labelrotation=45)


fig1, ax1 = plt.subplots(1,3, figsize=(20,5))

ax1[0].scatter(menu_dataset['Category'], menu_dataset['Total Fat (% Daily Value)'], edgecolor='black')
ax1[0].set_title('Total Fat (% Daily Value)', fontsize=14)
ax1[0].tick_params(labelrotation=45)

ax1[1].scatter(menu_dataset['Category'], menu_dataset['Sugars'],
               edgecolor='black')
ax1[1].set_title('Sugars', fontsize=14)
ax1[1].tick_params(labelrotation=45)

ax1[2].scatter(menu_dataset['Category'], menu_dataset['Vitamin A (% Daily Value)'], 
               edgecolor='black')
ax1[2].set_title('Vitamin A', fontsize=14)
ax1[2].tick_params(labelrotation=45)

# %% [markdown]
# From these plots, we can see that we need to identify what menu items are:
#
# - Low carb (less than 30) per meal
#
# - Low carbs daily (less than 40 kcal) per meal
#
# - high protein (over 10 no more than 30) per meal
#
# - Low total fat daily (less than 50) per meal
#
# - Low sugar (less than 20) per meal
#
# - High Vitamin A (more than 10) per meal

# %%
low_carb = menu_dataset[(menu_dataset['Carbohydrates'] <= 30) &
                        (menu_dataset['Carbohydrates (% Daily Value)'] <= 40) &
                        (menu_dataset['Protein'].between(0, 30)) &
                        (menu_dataset['Total Fat (% Daily Value)'] <= 50) &
                        (menu_dataset['Sugars'] <= 20) &
                        (menu_dataset['Vitamin A (% Daily Value)'] >= 10)]
low_carb
# Out:
#            Category                                               Item  \
# 3         Breakfast                          Sausage McMuffin with Egg
# 37        Breakfast                                    Sausage Burrito
# 84           Salads        Premium Bacon Ranch Salad (without Chicken)
# 85           Salads      Premium Bacon Ranch Salad with Crispy Chicken
# 86           Salads     Premium Bacon Ranch Salad with Grilled Chicken
# 87           Salads          Premium Southwest Salad (without Chicken)
# 89           Salads       Premium Southwest Salad with Grilled Chicken
# 100  Snacks & Sides                                         Side Salad
# 130       Beverages                                1% Low Fat Milk Jug
# 149    Coffee & Tea                                     Latte (Medium)
# 150    Coffee & Tea                                      Latte (Large)
# 161    Coffee & Tea  Latte with Sugar Free French Vanilla Syrup (Me...
# 163    Coffee & Tea                               Nonfat Latte (Small)
# 164    Coffee & Tea                              Nonfat Latte (Medium)
# 175    Coffee & Tea  Nonfat Latte with Sugar Free French Vanilla Sy...
# 176    Coffee & Tea  Nonfat Latte with Sugar Free French Vanilla Sy...
#
#           Serving Size  Calories  Calories from Fat  Total Fat  \
# 3       5.7 oz (161 g)       450                250       28.0
# 37      3.9 oz (111 g)       300                150       16.0
# 84      7.9 oz (223 g)       140                 70        7.0
# 85        9 oz (255 g)       380                190       21.0
# 86      8.5 oz (241 g)       220                 80        8.0
# 87      8.1 oz (230 g)       140                 40        4.5
# 89     11.8 oz (335 g)       290                 80        8.0
# 100      3.1 oz (87 g)        20                  0        0.0
# 130  1 carton (236 ml)       100                 20        2.5
# 149       16 fl oz cup       210                 90       10.0
# 150       20 fl oz cup       280                120       14.0
# 161       16 fl oz cup       260                 90       10.0
# 163       12 fl oz cup       100                  0        0.0
# 164       16 fl oz cup       130                  0        0.0
# 175       12 fl oz cup       140                  0        0.0
# 176       16 fl oz cup       170                  0        0.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 3                           43           10.0                             52
# 37                          25            7.0                             33
# 84                          11            3.5                             18
# 85                          33            6.0                             29
# 86                          13            4.0                             20
# 87                           7            2.0                              9
# 89                          13            2.5                             13
# 100                          0            0.0                              0
# 130                          4            1.5                              8
# 149                         16            6.0                             30
# 150                         21            8.0                             39
# 161                         16            6.0                             30
# 163                          0            0.0                              0
# 164                          0            0.0                              0
# 175                          0            0.0                              0
# 176                          0            0.0                              0
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 3          0.0  ...             30                             10
# 37         0.0  ...             26                              9
# 84         0.0  ...             10                              3
# 85         0.0  ...             22                              7
# 86         0.0  ...              8                              3
# 87         0.0  ...             20                              7
# 89         0.0  ...             28                              9
# 100        0.0  ...              4                              1
# 130        0.0  ...             12                              4
# 149        0.0  ...             18                              6
# 150        0.0  ...             24                              8
# 161        0.0  ...             29                             10
# 163        0.0  ...             15                              5
# 164        0.0  ...             19                              6
# 175        0.0  ...             24                              8
# 176        0.0  ...             30                             10
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 3                4                             17       2       21
# 37               1                              5       2       12
# 84               3                             12       4        9
# 85               2                             10       5       25
# 86               2                             10       4       29
# 87               6                             23       6        6
# 89               7                             28      10       27
# 100              1                              6       2        1
# 130              0                              0      12        8
# 149              1                              4      15       11
# 150              1                              6      20       15
# 161              1                              5      15       12
# 163              1                              3      13       10
# 164              1                              4      16       12
# 175              1                              4      13       10
# 176              1                              5      16       12
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 3                           15                          0
# 37                          10                          2
# 84                         170                         30
# 85                         100                         25
# 86                         110                         30
# 87                         160                         25
# 89                         170                         30
# 100                         45                         25
# 130                         10                          4
# 149                         10                          0
# 150                         15                          0
# 161                         10                          0
# 163                         10                          0
# 164                         15                          0
# 175                         10                          0
# 176                         15                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 3                         30                    15
# 37                        15                    15
# 84                        15                     6
# 85                        15                     8
# 86                        15                     8
# 87                        15                    10
# 89                        15                    15
# 100                        2                     4
# 130                       30                     0
# 149                       35                     0
# 150                       50                     2
# 161                       35                     0
# 163                       30                     0
# 164                       40                     0
# 175                       30                     0
# 176                       40                     0
#
# [16 rows x 24 columns]

# %% [markdown]
# Following the constraints above, these menu items are the best to consume if you are on a low carbohydrate diet. By no means must anyone follow this set menu or any of the other menus in this notebook.
#
# Now, in terms of analysis, we can see that a lot of the menu items are from the Coffee and Tea catagory, which was expected since beverages do not tend to be too high in fat or in protein. However, I was expecting to see more from the beverages catagory in terms of soft drinks with the title 'diet' (e.g. diet coke), since they are somewhat synonymous with dieting. But according to Mandl (2020), diet drinks can increase conusmer appetite causing them to consume more sweet or high calorie foods.
#
# Other than beverages, salads were recomended (which was expected) and breakfast items with sausage in them. Which was somewhat suprising due to the fact that I was expecting more eggs. This is because eggs are quite high in protein and are great for low carbohydrate diets according to Diabeties UK (2020).

# %% [markdown]
# ##### Next up, Low Fat diets.

# %% [markdown]
# ### Low Fat Diet
# Low fat diets are great for reducing cholesterol, cutting weight and any other issues related to reducting fat according to Meixner (2018). It is recomended that most adults should consume between <ins> 44 to 77 grams of fat daily </ins>, however, only if they eat at least 2000 calories a day, according to WebMD (No Date).

# %%
# Uses matplotlib's subplot function to create grouped scatter plots
# subplots parameters state that there will be a row of 2 plots with a size of 20 by 5
fig, ax = plt.subplots(1,2, figsize=(20,5))
# figsize=(12,5)
ax[0].scatter(menu_dataset['Category'], menu_dataset['Calories'], edgecolor='black')
ax[0].set_title('Calories', fontsize=14)
# sets the labels of the x axis to a 45 degree angle
ax[0].tick_params(labelrotation=45)

ax[1].scatter(menu_dataset['Category'], menu_dataset['Carbohydrates (% Daily Value)'],
               edgecolor='black')
ax[1].set_title('Carbohydrates Daily', fontsize=14)
ax[1].tick_params(labelrotation=45)


fig1, ax1 = plt.subplots(1,2, figsize=(20,5))

ax1[0].scatter(menu_dataset['Category'], menu_dataset['Total Fat (% Daily Value)'], edgecolor='black')
ax1[0].set_title('Total Fat (% Daily Value)', fontsize=14)
ax1[0].tick_params(labelrotation=45)

ax1[1].scatter(menu_dataset['Category'], menu_dataset['Protein'], edgecolor='black')
ax1[1].set_title('Protein', fontsize=14)
ax1[1].tick_params(labelrotation=45)

# %% [markdown]
# From these plots, we can see that we need to identify what menu items are:
#
#  - less calories less 500
#  - low fat daily less than 25
#  - low carb daily less than 40 kcal per meal
#  - high protein less than 30 per meal

# %%
low_fat = menu_dataset[(menu_dataset['Calories'] <= 400) &
                       (menu_dataset['Carbohydrates (% Daily Value)'] <= 40) &
                       (menu_dataset['Protein'] <= 30) &
                       (menu_dataset['Total Fat (% Daily Value)'] <= 25) &
                       (menu_dataset['Sugars'] <= 20)]
low_fat
# Out:
#          Category                                               Item  \
# 0       Breakfast                                       Egg McMuffin
# 1       Breakfast                                  Egg White Delight
# 20      Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 35      Breakfast                                           Hotcakes
# 37      Breakfast                                    Sausage Burrito
# ..            ...                                                ...
# 202  Coffee & Tea                       Hazelnut Iced Coffee (Small)
# 205  Coffee & Tea                 French Vanilla Iced Coffee (Small)
# 208  Coffee & Tea  Iced Coffee with Sugar Free French Vanilla Syr...
# 209  Coffee & Tea  Iced Coffee with Sugar Free French Vanilla Syr...
# 210  Coffee & Tea  Iced Coffee with Sugar Free French Vanilla Syr...
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 0    4.8 oz (136 g)       300                120       13.0
# 1    4.8 oz (135 g)       250                 70        8.0
# 20   6.3 oz (178 g)       400                140       15.0
# 35   5.3 oz (151 g)       350                 80        9.0
# 37   3.9 oz (111 g)       300                150       16.0
# ..              ...       ...                ...        ...
# 202    16 fl oz cup       130                 40        4.5
# 205    16 fl oz cup       120                 40        4.5
# 208    16 fl oz cup        80                 40        4.5
# 209    22 fl oz cup       120                 60        7.0
# 210    32 fl oz cup       160                 80        9.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                           20            5.0                             25
# 1                           12            3.0                             15
# 20                          24            7.0                             34
# 35                          13            2.0                              9
# 37                          25            7.0                             33
# ..                         ...            ...                            ...
# 202                          7            3.0                             15
# 205                          7            3.0                             15
# 208                          7            3.0                             15
# 209                         11            4.5                             22
# 210                         14            6.0                             29
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0          0.0  ...             31                             10
# 1          0.0  ...             30                             10
# 20         0.0  ...             47                             16
# 35         0.0  ...             60                             20
# 37         0.0  ...             26                              9
# ..         ...  ...            ...                            ...
# 202        0.0  ...             21                              7
# 205        0.0  ...             20                              7
# 208        0.0  ...              9                              3
# 209        0.0  ...             12                              4
# 210        0.0  ...             18                              6
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0                4                             17       3       17
# 1                4                             17       3       18
# 20               2                              9      16       20
# 35               3                             10      14        8
# 37               1                              5       2       12
# ..             ...                            ...     ...      ...
# 202              0                              0      20        1
# 205              0                              0      19        1
# 208              0                              0       1        1
# 209              0                              0       2        1
# 210              0                              0       2        2
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                           10                          0
# 1                            6                          0
# 20                           2                         10
# 35                           0                          0
# 37                          10                          2
# ..                         ...                        ...
# 202                          4                          0
# 205                          4                          0
# 208                          4                          0
# 209                          4                          0
# 210                          6                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 0                         25                    15
# 1                         25                     8
# 20                        15                    10
# 35                        15                    15
# 37                        15                    15
# ..                       ...                   ...
# 202                        4                     0
# 205                        4                     0
# 208                        4                     0
# 209                        4                     0
# 210                        8                     0
#
# [65 rows x 24 columns]

# %% [markdown]
# So in terms of low fat food, the Mcdonalds menu has quite a lot to offer, however, most of the menu items above are from the drinks section of the menu (as shown below), which is not suprising at all because quite a lot of beverages are usually low fat and low calorie.
#
# ![low%20fat%20.jpg](attachment:low%20fat%20.jpg)
#
# Besides drinks, the food menu options are quite varied and somewhat high in protein with multiple lean meat options. Which according to WebMD (No Date), is really good for controlling cholesterol, carbs and calories.

# %% [markdown]
# ##### Next up, low sodium diets

# %% [markdown]
# ### High Protein Diets
#
# High protein diets are great for reducing fat, and retaining muscle, however, doing them can create risks with kidneys, which is why according to Olsen (2019) doctors say not to do them if you have kidney disease. High protein diets encorage dieters to increase their protein intake and lower their carbohydrate intake.

# %%
# Uses matplotlib's subplot function to create grouped scatter plots
# subplots parameters state that there will be a row of 3 plots with a size of 20 by 5
fig, ax = plt.subplots(1,3, figsize=(20,5))
# figsize=(12,5)
ax[0].scatter(menu_dataset['Category'], menu_dataset['Protein'], edgecolor='black')
ax[0].set_title('Protein', fontsize=14)
# sets the labels of the x axis to a 45 degree angle
ax[0].tick_params(labelrotation=45)

ax[1].scatter(menu_dataset['Category'], menu_dataset['Carbohydrates (% Daily Value)'],
               edgecolor='black')
ax[1].set_title('Carbohydrates Daily', fontsize=14)
ax[1].tick_params(labelrotation=45)

ax[2].scatter(menu_dataset['Category'], menu_dataset['Calcium (% Daily Value)'], edgecolor='black')
ax[2].set_title('Calcium', fontsize=14)
ax[2].tick_params(labelrotation=45)


fig1, ax1 = plt.subplots(1,3, figsize=(20,5))

ax1[0].scatter(menu_dataset['Category'], menu_dataset['Total Fat (% Daily Value)'], edgecolor='black')
ax1[0].set_title('Total Fat (% Daily Value)', fontsize=14)
ax1[0].tick_params(labelrotation=45)

ax1[1].scatter(menu_dataset['Category'], menu_dataset['Sugars'],
               edgecolor='black')
ax1[1].set_title('Sugars', fontsize=14)
ax1[1].tick_params(labelrotation=45)

ax1[2].scatter(menu_dataset['Category'], menu_dataset['Saturated Fat (% Daily Value)'], 
               edgecolor='black')
ax1[2].set_title('Saturated Fat', fontsize=14)
ax1[2].tick_params(labelrotation=45)

# %% [markdown]
# From these plots, we can see that we need to identify what menu items are:
#
#  - high protein - 25 to 40
#  - low carb daily less than 40 kcal per meal
#  - low saturated fat daily - less than 45
#  - high calcium - 15 and above
#  - low sugar - less than 20
#  - reasonaly low fat - 30 or less

# %%
high_protein = menu_dataset[(menu_dataset['Calcium (% Daily Value)'] <= 400) &
                       (menu_dataset['Carbohydrates (% Daily Value)'] <= 40) &
                       (menu_dataset['Protein'].between(25, 40)) &
                       (menu_dataset['Total Fat (% Daily Value)'] <= 30) &
                       (menu_dataset['Saturated Fat (% Daily Value)'] <= 45) &
                       (menu_dataset['Sugars'] <= 20)]
high_protein
# Out:
#           Category                                               Item  \
# 58  Chicken & Fish           Premium Grilled Chicken Classic Sandwich
# 62  Chicken & Fish         Premium Grilled Chicken Ranch BLT Sandwich
# 71  Chicken & Fish   Premium McWrap Chicken & Bacon (Grilled Chicken)
# 73  Chicken & Fish   Premium McWrap Chicken & Ranch (Grilled Chicken)
# 77  Chicken & Fish  Premium McWrap Chicken Sweet Chili (Grilled Ch...
# 86          Salads     Premium Bacon Ranch Salad with Grilled Chicken
# 89          Salads       Premium Southwest Salad with Grilled Chicken
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 58     7 oz (200 g)       350                 80        9.0
# 62   7.6 oz (217 g)       450                130       15.0
# 71  10.7 oz (302 g)       480                170       19.0
# 73  10.5 oz (297 g)       450                160       18.0
# 77  10.3 oz (291 g)       380                 90       10.0
# 86   8.5 oz (241 g)       220                 80        8.0
# 89  11.8 oz (335 g)       290                 80        8.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 58                         13            2.0                              9
# 62                         23            4.5                             22
# 71                         28            7.0                             36
# 73                         27            6.0                             31
# 77                         15            3.0                             14
# 86                         13            4.0                             20
# 89                         13            2.5                             13
#
#     Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 58        0.0  ...             42                             14
# 62        0.0  ...             43                             14
# 71        0.0  ...             42                             14
# 73        0.5  ...             42                             14
# 77        0.0  ...             47                             16
# 86        0.0  ...              8                              3
# 89        0.0  ...             28                              9
#
#     Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 58              3                             13       8       28
# 62              3                             13       9       36
# 71              3                             13       6       36
# 73              3                             14       6       30
# 77              3                             13      12       27
# 86              2                             10       4       29
# 89              7                             28      10       27
#
#     Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 58                          4                          8
# 62                          4                         20
# 71                         60                         25
# 73                         60                         15
# 77                         60                         15
# 86                        110                         30
# 89                        170                         30
#
#     Calcium (% Daily Value)  Iron (% Daily Value)
# 58                       15                    20
# 62                       15                    20
# 71                       20                    20
# 73                       15                    20
# 77                        8                    20
# 86                       15                     8
# 89                       15                    15
#
# [7 rows x 24 columns]

# %% [markdown]
# In terms of analysis, this is pretty much what I was expecting, however, I feel like more burgers should be recomended too especially beef burgers because according to WebMD (No Date) lean beef is extremely high in protein without the fat. Grilled chicken comes up alot because it has little fat making it perfect for high protein diets.

# %% [markdown]
# References:
#
# Drawing From Data Available(No date). Avaliable from: https://www.drawingfromdata.com/how-to-rotate-axis-labels-in-seaborn-and-matplotlib [Accessed on 26 October 2020]
#
# Lock. S. (2020) Statista. Available from: https://www.statista.com/statistics/219454/mcdonalds-restaurants-worldwide/ [Accessed on 26 October 2020]
#
# The Association of UK Dietitians (No date). Avaliable from: https://www.bda.uk.com/resource/plant-based-diet.html [Accessed on 03 November 2020]
#
# dictionary.com (No Date). Avaliable from: https://www.dictionary.com/e/pop-culture/paleo-diet/ [Accessed on 03 November 2020]
#
# Bjarnadottir. A. (2019) healthline. Avaliable from: https://www.healthline.com/nutrition/9-weight-loss-diets-reviewed#TOC_TITLE_HDR_4 [Accessed on 03 November 2020]
#
# Diabetes UK (No Date). Avalible From: https://www.diabetes.org.uk/guide-to-diabetes/enjoy-food/eating-with-diabetes/meal-plans/low-carb [Accessed on 04 November 2020]
#
# Accessed 14th nov
# NHS. (No Date). Avaliable from: https://www.nhs.uk/live-well/eat-well/how-does-sugar-in-our-diet-affect-our-health/#:~:text=Products%20are%20considered%20to%20either,of%20total%20sugars%20per%20100g [Accessed 14th November 2020]
#
# Spritzler. F. (2020). Diet Doctor. Avaliable from: https://www.dietdoctor.com/low-carb/protein [Accessed 14th November 2020]
#
# Spritzler. F. (2020). Diet Doctor. Avaliable from: https://www.dietdoctor.com/low-carb/saturated-fat
#
# Mandl. E (2020) healthline. Avaliable from: https://www.healthline.com/nutrition/diet-soda-good-or-bad#weight-loss [Accessed 16 November 2020]
#
# Meixner. M (2018) healthline. Avaliable from: https://www.healthline.com/nutrition/healthy-low-fat-foods [Accessed 16 November 2020]
#
# WebMD. (No Date) Avaliable from: https://www.webmd.com/women/reducing-dietary-fat#1 [Accessed 16 November 2020]
#
# Olsen. M (2019) Medical News Today. Avaliable from: https://www.medicalnewstoday.com/articles/324915 [Accessed 16 November 2020]
#
# WebMD (No Date). Avaliable at: https://www.webmd.com/diet/ss/slideshow-high-protein-diet [Accessed 16 November 2020]
